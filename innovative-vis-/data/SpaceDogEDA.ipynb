# %%
import pandas as pd
import numpy as np

# %%
dogs = pd.read_csv("Dogs-Database.csv")

# %%
Flight=pd.read_csv("Flights-Database.csv")

# %%
dogs
# Out:
#                  Name (Latin)                   Name (English)  \
# 0                       Dezik                            Dezik
# 1                      Tsygan                            Gypsy
# 2                        Lisa                              Fox
# 3                     Chizhik                           Siskin
# 4                      Mishka                      Little Bear
# 5                      Ryzhik                           Ginger
# 6                      Smeliy                       Courageous
# 7                   Neputeviy                            Scamp
# 8                         ZIB     Substitute for Missing Bobik
# 9                      Lisa-2                              Fox
# 10                   Ryzhik-2                           Ginger
# 11                      Damka                      Little Lady
# 12                   Mishka-2                      Little Bear
# 13                   Ryzhik-3                           Ginger
# 14                       Rita                             Rita
# 15                      Linda                            Linda
# 16                      Bulba                            Bulba
# 17                     Knopka                           Button
# 18                   Malyshka                       Little One
# 19                     Albina                           Whitey
# 20                   Kozyavka                      Little Gnat
# 21                    Damka-2                      Little Lady
# 22                    Dzhoyna                          Dzhoyna
# 23                    Ryzhaya                          Redhead
# 24                      Belka                         Squirrel
# 25                   Modnitsa                      Fashionable
# 26                      Laika                           Barker
# 27                      Palma                             Palm
# 28                     Pushok                           Fluffy
# 29      Kusachka / Otvazhnaya                Biter / Brave One
# 30                    Palma-2                             Palm
# 31                   Belyanka                    Little Whitey
# 32                   Pestraya                          Spotted
# 33                     Zhulba                           Zhulba
# 34  Snezhinka / Zhemchuzhnaya               Snowflake / Pearly
# 35                     Malyok                        Small Fry
# 36                   Lisichka                       Little Fox
# 37              Bars / Chaika                Panther / Seagull
# 38                    Strelka                     Little Arrow
# 39                       Neva                             Neva
# 40                     Mushka                       Little Fly
# 41                   Pchyolka                       Little Bee
# 42                     Shutka                             Joke
# 43                 Chernuskha                          Blackie
# 44                    Kometka                            Comet
# 45                 Zvezdochka                      Little Star
# 46          Ugolyok / Snezhok  Little Piece of Coal / Snowball
# 47          Veterok / Bzdunok        Little Wind / Little Fart
#
#                Name (Cyrillic)  Gender  \
# 0                        Дезик    Male
# 1                        Цыган    Male
# 2                         Лиса  Female
# 3                        Чижик    Male
# 4                        Мишка    Male
# 5                        Рыжик    Male
# 6                       Смелая    Male
# 7                    Непутёвый    Male
# 8   Замена Исчезнувшему Бобику    Male
# 9                         Лиса  Female
# 10                       Рыжик    Male
# 11                       Дамка  Female
# 12                       Мишка    Male
# 13                       Рыжик    Male
# 14                        Рита  Female
# 15                        Лида  Female
# 16                      Бульба  Female
# 17                      Кнопка  Female
# 18                     Малышка  Female
# 19                     Альбина  Female
# 20                     Козявка  Female
# 21                       Дамка  Female
# 22                      Джойна  Female
# 23                       Рыжая  Female
# 24                       Белка  Female
# 25                     Модница  Female
# 16                Died 1955-02-05
# 17                Died 1958-10-31
# 18                       Survived
# 19                       Survived
# 20                       Survived
# 21                       Survived
# 22                Died 1957-05-24
# 23                Died 1957-05-24
# 24                       Survived
# 25                       Survived
# 26                Died 1957-11-03
# 27                Died 1958-02-21
# 28                Died 1958-02-21
# 29                       Survived
# 30                       Survived
# 31                       Survived
# 32                       Survived
# 33                Died 1958-10-31
# 34                       Survived
# 35                       Survived
# 36                Died 1960-07-28
# 37                Died 1960-07-28
# 38                       Survived
# 39                       Survived
# 40                Died 1960-12-01
# 41                Died 1960-12-01
# 42                       Survived
# 43                       Survived
# 44                       Survived
# 45                       Survived
# 46                       Survived
# 47                       Survived
#
#                                                 Notes
# 0                                                 NaN
# 1   Adopted as a pet by Soviet physicist Anatoli B...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   An untrained street dog found running around t...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26  Also known as Kudryavka (Little Curly) and Lim...
# 27                                                NaN
# 28                                                NaN
# 29            Made the most flights of any space dog.
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38  Went on to have six puppies with a male dog na...
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42  Also known as Damka (Little Lady) and Zhemchuz...
# 43                                                NaN
# 44  Also known as Krasavka (Cheater) and Zhulka (B...
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN

# %%
dogs.describe()
# Out:
#        Name (Latin) Name (English) Name (Cyrillic)  Gender     Flights  \
# count            48             48              48      48          48
# unique           48             42              42       2          39
# top      Zvezdochka         Ginger           Рыжик  Female  1960-07-28
# freq              1              3               3      33           2
#
#             Fate                                              Notes
# count         48                                                  7
# unique        13                                                  7
# top     Survived  An untrained street dog found running around t...
# freq          28                                                  1

# %%
def cal(a,b,c,d):
    sum1=a+b+c+d
    return [a/sum1,b/sum1,c/sum1,d/sum1]

# %%
cal(1,1,9,3)
# Out:
# [0.07142857142857142,
#  0.07142857142857142,
#  0.6428571428571429,
#  0.21428571428571427]

# %%
a={'1951':[{label: 'SurvivedMaleDog', value:45, name:'Gypsy(Adopted as a pet by Soviet physicist Anatoli Blagonravov),Ginger,Courageous,Scamp,Bobik(An untrained street dog found running around the barracks, captured after Bobik ran away days before his flight)'},
           {label: 'DiedMaleDog', value:36, name:'Dezik,Siskin,little Bear'},
           {label: 'SurvivedFemaleDog', value:10, name:'Ginger'},
           {label: 'DiedFemaleDog', value:9,name:'Fox'}
          ],
   '1954':[{label: 'SurvivedMaleDog', value:17, name:'Ginger2'},
           {label: 'DiedMaleDog', value:33, name:'Little Bear,Ginger'},
           {label: 'SurvivedFemaleDog', value:50, name:'Little Lady1,Little Lady2,Fox'},
           {label: 'DiedFemaleDog', value:0,name:''}
          ],
   '1955':[{label: 'SurvivedMaleDog', value:0, name:''},
           {label: 'DiedMaleDog', value:0, name:''},
           {label: 'SurvivedFemaleDog', value:50, name:'Linda,Little One,Button'},
           {label: 'DiedFemaleDog', value:50,name:'Rita,Fox,Bulba'}
          ],
   '1956':[{label: 'SurvivedMaleDog', value:0, name:''},
           {label: 'DiedMaleDog', value:0, name:''},
           {label: 'SurvivedFemaleDog', value:100, name:'Whitey1,Little Gnat,Linda,Little One'},
           {label: 'DiedFemaleDog', value:0,name:''}
          ],
   '1957':[{label: 'SurvivedMaleDog', value:0, name:''},
           {label: 'DiedMaleDog', value:0, name:''},
           {label: 'SurvivedFemaleDog', value:57, name:'Little Lday,Squirrel,Fashionable,Squirrel'},
           {label: 'DiedFemaleDog', value:43, name:'Dzhoyna,Redhead,Barker'}
          ],
   '1958':[{label: 'SurvivedMaleDog', value:0, name:''},
           {label: 'DiedMaleDog', value:10, name:'Fluffy'},
           {label: 'SurvivedFemaleDog', value:60, name:'Biter/Brave one(Made the most flights of any space dog),Palm,Little Whitey,Spotted,Little Gnat,Little Lady'},
           {label: 'DiedFemaleDog', value:30,name:'Palm,Button,Zhulba'}
          ],
   '1959':[{label: 'SurvivedMaleDog', value:0, name:''},
           {label: 'DiedMaleDog', value:0, name:''},
           {label: 'SurvivedFemaleDog', value:100, name:'Biter/Brave One(Made the most flights of any space dog),Snowflake / Pearly'},
           {label: 'DiedFemaleDog', value:0,name:''}
          ],
   '1960':[{label: 'SurvivedMaleDog', value:7, name:'Small Fry'},
           {label: 'DiedMaleDog', value:7, name:'Little Fly'},
           {label: 'SurvivedFemaleDog', value:64, name:'Biter/Brave One(Made the most flights of any space dog),Snowflake/Pearly,Squirrel,Little Arrow(Went on to have six puppies with a male dog named Pushok who participated in many ground-based space experiments, but never made it into space),Palm,Neva,Joke,Comet'},
           {label: 'DiedFemaleDog', value:22,name:'Little Fox,Panther/Seagull,Little Bee'}
          ],
   '1961':[{label: 'SurvivedMaleDog', value:50, name:'Little Piece of Coal/Snowball,Little Wind/Little Fart'},
           {label: 'DiedMaleDog', value:0, name:''},
           {label: 'SurvivedFemaleDog', value:50, name:'Blackie,Little Star'},
           {label: 'DiedFemaleDog', value:0,name:''}
          ],
  }
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-a333b090ee8f> in <module>
# ----> 1 a={'1951':[{label: 'SurvivedMaleDog', value:45, name:'Gypsy,Ginger,Courageous,Scamp,Bobik'},
#       2            {label: 'DiedMaleDog', value:36, name:'Dezik,Siskin,little Bear'},
#       3            {label: 'SurvivedFemaleDog', value:10, name:'Ginger'},
#       4            {label: 'DiedFemaleDog', value:9,name:'Fox'}
#       5           ],
#
# NameError: name 'label' is not defined

# %%
a['1951']
# Out:
# [{'label': 'MaleDog', 'value': 3},
#  {'label': 'DiedMaleDog', 'value': 2},
#  {'label': 'FemaleDog', 'value': 2},
#  {'label': 'DiedFemaleDog', 'value': 0}]

# %%
d
